# %% [markdown]
# For plotting make sure to install jupyter notebook and matplotlib first:
# ```
# conda install jupyter notebook
# pip install matplotlib
# ```

# %%
import sys
import os

sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(__file__))))

from plotting import plot_best_worst

# %%
PATH = f"..."
IMGS = "/0/imgs"
UNC = "/entropy_clip.npy"

# %%
plot_best_worst(exp_img=PATH, imgs=IMGS, exp=PATH, unc=UNC, dpi=200)
# Out:
# [ 1202  6511  2018 11980  4464  5340  8223  4250 11058  4234  3715  8858
#  10211 11119 11457 10622  9384  3939  8860  1175  4306    19  1582  2873
#   5200]
# [ 2304  2648  9465  1959  4742  3224  2731  2185  8526  4890  6719  5559
#  10621  7791 10559  5100  1844  9155  8021  3229 11014  5809  5883  2402
#   3334]
