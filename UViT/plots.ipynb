# %% [markdown]
# For plotting make sure to install jupyter notebook and matplotlib first:
# ```
# conda install jupyter notebook
# pip install matplotlib
# ```

# %%
import sys
import os

# Add parent directory to path
sys.path.append('..')

from plotting import plot_best_worst

# %%
PATH = f"..."
IMGS = "/0/imgs"
UNC = "/entropy_clip.npy"

# %%
plot_best_worst(exp_img=PATH, imgs=IMGS, exp=PATH, unc=UNC, dpi=200)
# Out:
# [ 1873  8130  2188 11025  2170  9262 11046  9983   139  2224  5897  1430
#      9  8190 10085   200 10743  5969  3008  5737 11505  5146  4771   828
#   9888]
# [ 5116  7308  9250  5961  3491  3173  8857  7645  3215  9687   381  7992
#   9720  4355  8542 11527   181  4220 10664  6541  3003  6743  4484   778
#   5088]
